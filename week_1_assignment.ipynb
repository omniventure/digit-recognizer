# %% [markdown]
# # Week 1 Assignment
# CNN Image Classification using the Modified National Institute of Standards and Technology Dataset

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 64
path = untar_data(URLs.MNIST); path
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/mnist_png/testing'),
#  PosixPath('/root/.fastai/data/mnist_png/training')]

# %%
tfms = get_transforms(do_flip=False)
data = ImageDataBunch.from_folder(path, 
                                  ds_tfms=tfms, 
                                  size=224, 
                                  bs=bs, 
                                  train='training', 
                                  valid='testing').normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
learn = cnn_learner(data, models.resnet34, metrics = accuracy)
learn.model
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# 100%|██████████| 87306240/87306240 [00:02<00:00, 41876943.43it/s]
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.122777</td>
#       <td>0.065043</td>
#       <td>0.978100</td>
#       <td>08:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.073024</td>
#       <td>0.032016</td>
#       <td>0.989900</td>
#       <td>08:41</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.041922</td>
#       <td>0.022804</td>
#       <td>0.992000</td>
#       <td>08:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.034682</td>
#       <td>0.021541</td>
#       <td>0.992600</td>
#       <td>08:39</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('round-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses, idxs = interp.top_losses()
len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_confusion_matrix(figsize=(10,10), dpi=60)

# %%
interp.plot_top_losses(6, figsize=(5,5))

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.029364</td>
#       <td>0.012369</td>
#       <td>0.995900</td>
#       <td>10:09</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Extra Credit

# %% [markdown]
# The confusion matrix displays the accuracy of your classifier. It will list correct classifications predicted in the diagonal of the table whereas the misclassified actual/predicted class around the correct classifications.
#
# The plot top losses displays the top misclassified classes with the actual known and the probability of the predictions.
